# %%
import pandas as pd 
import matplotlib.pyplot as plt 
plt.rcParams["font.sans-serif"]=['SimHei'] #设置字体

# %%
df = pd.read_spss(R'data\identity.sav')

# %%
#无序类别变量的描述统计
df['政治面貌'].value_counts(normalize=True) 
#normalize=True 百分比 默认由大到小排序
# Out:
# 政治面貌
# 团员    0.734104
# 党员    0.130636
# 群众    0.110983
# 其他    0.024277
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt 
数据表 = ['A', 'B', 'C', 'D']
变量 = [30, 25, 20, 25]

# %%
plt.pie(变量, labels=数据表, autopct='%1.1f%%') 
plt.show()
