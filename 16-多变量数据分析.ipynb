# %%
# 读取上传的 Excel 文件
import pandas as pd
file_path_excel = R'data\国家认同数据清理后.xlsx'
df_excel = pd.read_excel(file_path_excel)
# 创建年级、政治面貌和会打多少分的交互表
cross_tab = pd.crosstab(index=[df_excel['年级'], df_excel['会打多少分']], 
                        columns=df_excel['政治面貌'], 
                        margins=True,normalize = True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌              1         2         3         4       All
# 年级  会打多少分
# 0   3      0.005135  0.000000  0.000000  0.000000  0.005135
#     4      0.008986  0.000000  0.000000  0.000000  0.008986
#     5      0.001284  0.000000  0.001284  0.000000  0.002567
# 1   1      0.006418  0.000000  0.001284  0.000000  0.007702
#     2      0.010270  0.000000  0.001284  0.000000  0.011553
#     3      0.032092  0.005135  0.003851  0.003851  0.044929
#     4      0.151476  0.007702  0.016688  0.000000  0.175866
#     5      0.091142  0.002567  0.010270  0.000000  0.103979
# 2   1      0.011553  0.001284  0.000000  0.000000  0.012837
#     2      0.012837  0.001284  0.001284  0.000000  0.015404
#     3      0.043646  0.011553  0.016688  0.001284  0.073171
#     4      0.110398  0.007702  0.010270  0.003851  0.132221
#     5      0.066752  0.012837  0.005135  0.001284  0.086008
# 3   1      0.003851  0.002567  0.002567  0.000000  0.008986
#     2      0.002567  0.001284  0.000000  0.000000  0.003851
#     3      0.025674  0.010270  0.006418  0.001284  0.043646
#     4      0.048780  0.033376  0.015404  0.005135  0.102696
#     5      0.030809  0.008986  0.003851  0.003851  0.047497
# 4   1      0.000000  0.002567  0.000000  0.000000  0.002567
#     2      0.001284  0.000000  0.001284  0.000000  0.002567
#     3      0.010270  0.005135  0.005135  0.000000  0.020539
#     4      0.037227  0.007702  0.005135  0.000000  0.050064
#     5      0.024390  0.010270  0.002567  0.000000  0.037227
# All        0.736842  0.132221  0.110398  0.020539  1.000000

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = 2

# 筛选出特定年级的数据
df_specific_grade = df_excel[df_excel['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['会打多少分'], df_specific_grade['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

chi2_grade, p_grade, dof_grade, expected_grade[:10]  # 展示期望频次的前10个结果，避免过长的输出
# Out:
# (20.269905911839633,
#  0.06214943009111473,
#  12,
#  array([[ 7.67068273,  1.08433735,  1.04417671,  0.20080321],
#         [ 9.20481928,  1.30120482,  1.25301205,  0.24096386],
#         [43.72289157,  6.18072289,  5.95180723,  1.14457831],
#         [79.00803213, 11.1686747 , 10.75502008,  2.06827309],
#         [51.3935743 ,  7.26506024,  6.99598394,  1.34538153]]))

# %%
import pandas as pd  
import mytools
df_spss = pd.read_spss(R'data\国家认同数据清理后.sav')
cross_tab = pd.crosstab(index=[df_spss['年级'], df_spss['您觉得自己是个典型的中国人吗']], 
                        columns=df_spss['政治面貌'], 
                        margins=True,normalize = True)
cross_tab
# Out:
# 政治面貌                      党员        其他        团员        群众       All
# 年级  您觉得自己是个典型的中国人吗
# 大一  一般般             0.000000  0.000000  0.048780  0.001284  0.050064
#     不太算             0.001284  0.001284  0.010270  0.001284  0.014121
#     可以算             0.005135  0.001284  0.070603  0.011553  0.088575
#     完全不是            0.000000  0.001284  0.008986  0.002567  0.012837
#     完全是             0.008986  0.000000  0.152760  0.016688  0.178434
# 大三  一般般             0.003851  0.001284  0.021823  0.008986  0.035944
#     不太算             0.006418  0.000000  0.005135  0.003851  0.015404
#     可以算             0.026958  0.003851  0.043646  0.008986  0.083440
#     完全是             0.019255  0.005135  0.041078  0.006418  0.071887
# 大二  一般般             0.005135  0.000000  0.033376  0.001284  0.039795
#     不太算             0.008986  0.000000  0.015404  0.005135  0.029525
#     可以算             0.006418  0.003851  0.074454  0.007702  0.092426
#     完全不是            0.000000  0.000000  0.008986  0.000000  0.008986
#     完全是             0.014121  0.002567  0.112965  0.019255  0.148909
# 大四  一般般             0.002567  0.000000  0.015404  0.002567  0.020539
#     不太算             0.001284  0.000000  0.002567  0.000000  0.003851
#     可以算             0.006418  0.000000  0.017972  0.005135  0.029525
#     完全不是            0.002567  0.000000  0.000000  0.001284  0.003851
#     完全是             0.012837  0.000000  0.037227  0.005135  0.055199
# 预科  一般般             0.000000  0.000000  0.010270  0.000000  0.010270
#     可以算             0.000000  0.000000  0.001284  0.000000  0.001284
#     完全是             0.000000  0.000000  0.003851  0.001284  0.005135
# All                 0.132221  0.020539  0.736842  0.110398  1.000000

# %%
from scipy import stats
specific_grade = '大二'
df_specific_grade = df_spss[df_spss['年级'] == specific_grade]
cross_tab_specific_grade = pd.crosstab(df_specific_grade['政治面貌'],
                                       df_specific_grade['您觉得自己是个典型的中国人吗'], 
                                       margins=True,normalize = True)
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)
print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 0.08097949499182183 1.0
# 您觉得自己是个典型的中国人吗       一般般       不太算       可以算      完全不是       完全是       All
# 政治面貌
# 党员              0.016064  0.028112  0.020080  0.000000  0.044177  0.108434
# 其他              0.000000  0.000000  0.012048  0.000000  0.008032  0.020080
# 团员              0.104418  0.048193  0.232932  0.028112  0.353414  0.767068
# 群众              0.004016  0.016064  0.024096  0.000000  0.060241  0.104418
# All             0.124498  0.092369  0.289157  0.028112  0.465863  1.000000

# %%
mytools.两个无序类别变量的统计分析(df_specific_grade,'政治面貌','您觉得自己是个典型的中国人吗')
# Out:
# tau_y系数: 0.0165 极弱相关或无相关
# ----  --  --  --  -  --
# 党员   4   7   5  0  11
# 其他   0   0   3  0   2
# 团员  26  12  58  7  88
# 群众   1   4   6  0  15
# ----  --  --  --  -  --
# 卡方值： 20.16, p值： 0.0640,自由度:12。
# 接受虚无假设
